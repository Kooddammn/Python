# %% [markdown]
# # Python Baics Project

# %% [markdown]
# ## This Project Contains Python Basics Project

# %%
print("This is the first jupyter notebook code")
# Out:
# This is the first jupyter notebook code
