# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.8 MB 2.8 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/9.8 MB 2.8 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.8 MB 2.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.8 MB 2.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.8 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.8 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 2.9 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.8 MB 2.9 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.8 MB 2.9 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np

s = pd.Series(data=[10,20,30],index=["Bread","milk","butter"],name="Price of Grocery Items")
t = pd.Series(data=[10,20,30,40,50],index=['a','b','c','d','e'])
print(t.loc['a':'d'])
print(t.iloc[0:3])
print(t.loc[['a','b','c']])
print(t.iloc[[0,4,2]])
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
# a    10
# e    50
# c    30
# dtype: int64

# %%
s = pd.Series([10,None,20,None,30])
print(s.isnull())
print(s.notnull())
print(s.isnull().sum())
print(s.dropna())
print(s.fillna(0))
print(s.fillna(method='bfill'))
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool
# 2
# 0    10.0
# 2    20.0
# 4    30.0
# dtype: float64
# 0    10.0
# 1     0.0
# 2    20.0
# 3     0.0
# 4    30.0
# dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       3 print(s.notnull())
#       4 print(s.isnull().sum())
#       5 print(s.dropna())
#       6 print(s.fillna(0))
# ----> 7 print(s.fillna(method='bfill'))
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'method'

# %%
# From dictionary (keys = column names)
data = {
'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
'Age': [25, 30, 35, 28],
'Score': [88.5, 92.0, 79.5, 95.0],
'City': ['Mumbai', 'Delhi', 'Pune', 'Chennai']
}
df = pd.DataFrame(data)
print(df)
# From list of dicts
rows = [{'Name':'Alice','Age':25}, {'Name':'Bob','Age':30}]
df2 = pd.DataFrame(rows)
print(df2)
# From NumPy array
import numpy as np
arr = np.random.randint(1,100,(4,3))
df3 = pd.DataFrame(arr, columns=['A','B','C'])
print(df3)
# Out:
#       Name  Age  Score     City
# 0    Alice   25   88.5   Mumbai
# 1      Bob   30   92.0    Delhi
# 2  Charlie   35   79.5     Pune
# 3    Diana   28   95.0  Chennai
#     Name  Age
# 0  Alice   25
# 1    Bob   30
#     A   B   C
# 0  57  47  89
# 1  86  60  24
# 2  42  16  11
# 3  93  77  57
