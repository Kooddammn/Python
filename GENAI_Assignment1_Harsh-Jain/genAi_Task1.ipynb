# %%
# created a list named product containing product name
products = ["headphone","Tshirt","Cups","Laptop","Medicines","bottle","shoes","utensils","chair","books","plants"]

# %%
#created a tuple named sample_product that stores productname, price and category
sample_product = ("air fryer",1200,"Kitchenware")

# %%
#print second and the last item from the product list
print(products[1],products[-1])
# Out:
# Tshirt plants

# %%
#appendedn two new product in the product list and print the list
products.append("hair dryer")
products.append("crockery")
print(products)
# Out:
# ['headphone', 'Tshirt', 'Cups', 'Laptop', 'Medicines', 'bottle', 'shoes', 'utensils', 'chair', 'books', 'plants', 'hair dryer', 'crockery']

# %%
#convert smaple_product tuple into list update the price and convert it back to tuple
my_sample_product = list(sample_product)
my_sample_product[1] = 1300
my_tuple_product = tuple(my_sample_product)
print(my_tuple_product)
# Out:
# ('air fryer', 1300, 'Kitchenware')
