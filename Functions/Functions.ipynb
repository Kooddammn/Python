# %% [markdown]
# ## Function is a block of code that perfom a specific task.
# ## Function helps in organizing code , reusing code and imporving readability.

# %% [markdown]
# ## Syutax for function
# ## def func_name(parameters)
# ##  """Purpose of the function"""
# ##   function Body
# ##  return expression

# %%
## ftunction for translating from englis to hindi language

def translator(Englisghtext):
    if English_text =="Hello" or English_text == "hello":
        print(f"Translation for {English_text} is Namaste")

# %% [markdown]
# ## for having the acces to function and to provide the input to our function we can simply call the function

# %%
def even_or_odd(num):
    if isinstance(num, int):
        if num % 2 == 0:
            print("Number is Even")
        else:
            print("Number is odd")
    elif isinstance(num, str):
        print("Invalid data type")
    else :
        print(f"{num} Number is not valid for this function")
even_or_odd(100)
even_or_odd(123)
even_or_odd('gfh')
even_or_odd(True)
even_or_odd(65.3)
# Out:
# Number is Even
# Number is odd
# Invalid data type
# Number is odd
# 65.3 Number is not valid for this function

# %%
print("Hello World!", end=" ")
print("I will write in the same line")
# Out:
# Hello World! I will write in the same line
