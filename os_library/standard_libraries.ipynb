# %%
from math import *
number = int(input("Enter number"))
print(sqrt(number))
# Out:
# 3.4641016151377544

# %%
import random 
print(random.randint(100,9999))
print(random.choices(['apple','mango','banana','pineapple','lichi','grapes']))
# Out:
# 1810
# ['apple']

# %%
import csv
with open('file.txt',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Harsh','23'])

# %%
with open('file.txt',mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Harsh', '23']

# %%
from datetime import datetime, timedelta
timedate = datetime.now()
print(timedate)
yesterdaytime = timedate - timedelta(days=1)
print(yesterdaytime)
# Out:
# 2026-06-20 16:43:56.034413
# 2026-06-19 16:43:56.034413

# %%
import shutil
shutil.copyfile('source_file.txt','destination.txt')
# Out:
# 'destination.txt'
