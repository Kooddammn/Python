# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# c:\Users\jainh\OneDrive\Documents\RootDocumentFolder\Projects\Python\os_library

# %%
new_folder = "new_folder"
os.mkdir(new_folder)

# %%
all_items = os.listdir('.')
print("",all_items)
# Out:
#  ['new_folder', 'os_library.ipynb']

# %%
dir_name = "Folder_name"
file_name = "File_name"
full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# Folder_name\File_name

# %%
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# c:\Users\jainh\OneDrive\Documents\RootDocumentFolder\Projects\Python\os_library\Folder_name\File_name

# %%
if os.path.exists(full_path):
    print("The path exists")
else:
    print("The path does not exists")
# Out:
# The path does not exists

# %%
path_file ='file.txt'
if os.path.isfile(path_file):
    print("This is the file")
elif os.path.isdir(path_file):
    print("This is a dir")
else:
    print("The current path is not file or dir")
# Out:
# This is the file
